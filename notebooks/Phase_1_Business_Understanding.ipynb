# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# TODO: Define business objectives here.
# Example:
# business_objectives = {
#     "background": "Describe the organisational context and business area...",
#     "primary_objective": "What is the main business question or problem?",
#     "success_criteria": [
#         "Criterion 1: e.g., Reduce X by Y%",
#         "Criterion 2: e.g., Achieve Z accuracy"
#     ]
# }

business_objectives = {
    "background": (
        "ROSSMANN is one of the largest drug store chains in Europe. "
        "ROSSMANN was founded by Dirk Rossmann in 1972 in Hanover. "
        "ROSSMANN is the first German brand to introduce discount health and beauty retail concept. "
        "As of 2026, ROSSMANN operates 5,209 stores, all across 9 countries, mostly in Europe."
    ),
    "primary_objective": (
        "To accurately forecast daily sales revenue 6 weeks in advance to ensure inventory levels "
        "are sufficient for the 'Holiday Season' without overstocking. "
        "To determine the marginal lift in sales caused by 'Promo' events and evaluate if this "
        "lift justifies the cost of the discount. "
),
    "success_criteria": [
        "Criterion 1: Achieve a high-precision sales forecast that allows for stable inventory planning 6 weeks out.",
        "Criterion 2: Quantify the financial 'lift' of promotions to inform future marketing spend.",
        "Criterion 3: Provide actionable insights into the impact of State and School holidays on revenue.",
        "Criterion 4: Evaluate the ethical implications and potential biases of the model across different store locations."
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    ROSSMANN is one of the largest drug store chains in Europe. ROSSMANN was founded by Dirk Rossmann in 1972 in Hanover. ROSSMANN is the first German brand to introduce discount health and beauty retail concept. As of 2026, ROSSMANN operates 5,209 stores, all across 9 countries, mostly in Europe.
#
# >> PRIMARY OBJECTIVE:
#    To accurately forecast daily sales revenue 6 weeks in advance to ensure inventory levels are sufficient for the 'Holiday Season' without overstocking. To determine the marginal lift in sales caused by 'Promo' events and evaluate if this lift justifies the cost of the discount.
#
# >> SUCCESS CRITERIA:
#    - Criterion 1: Achieve a high-precision sales forecast that allows for stable inventory planning 6 weeks out.
#    - Criterion 2: Quantify the financial 'lift' of promotions to inform future marketing spend.
#    - Criterion 3: Provide actionable insights into the impact of State and School holidays on revenue.
#    - Criterion 4: Evaluate the ethical implications and potential biases of the model across different store locations.

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# TODO: Assess the current situation here.
# Document resources, requirements, assumptions, constraints, and risks.

situation_assessment = {
    "resources": {
        "personnel": ["Data Science Student"],      # e.g., ["Data Scientist", "Domain Expert"]
        "data_sources": ["Rossmann Store Sales Dataset [Kaggle]"],   # e.g., ["Internal DB", "Public API", "CSV files"]
        "computing": "Local Machine/VS Code environment",      # e.g., "Local machine / Cloud platform"
        "software": ["Python 3.10", "Pandas", "Scikit-learn", "Jupyter"]        # e.g., ["Python 3.x", "scikit-learn", "pandas"]
    },
    "requirements": [
        "Project must follow CRISP-DM framework",
        "Final report due 14th April 2026",
        "Code must be modular and PEP8 compliant"
    ],       # e.g., ["Must comply with GDPR", "Deadline: DD/MM/YYYY"]
    "assumptions": [
        "Historical sales patterns from 2015 are applicable for predictive modeling",
        "External holiday data can be successfully merged with store data"
        "Inventory must be optimized and not just raw prediction accuracy"
        ],        # e.g., ["Data is representative of the population"]
    "constraints": [
        "Individual project which means no collaboration allowed",
        "Computing power limited to local hardware"
    ],        # e.g., ["Limited to 10,000 records", "No budget for cloud"]
    "risks_and_contingencies": [
        {
            "risk": "Data quality issues (missing values in store.csv)",
            "probability": "High",
            "mitigation": "Perform rigorous data auditing and imputation in Phase 2/3"
        },
        {
            "risk": "Scraping failure due to website layout changes",
            "probability": "Medium",
            "mitigation": "Use robust selectors and have a static backup CSV of external data if live scraping fails."
        },
        {
            "risk": "Data leakage (using future information to predict the past)",
            "probability": "Medium",
            "mitigation": "Maintain a strict temporal split between training and test sets during Phase 4."
        }
        # {"risk": "Description", "probability": "Low/Medium/High", "mitigation": "Plan"}
    ],
    "terminology": {
        "MAPE": "Mean Absolute Percentage Error",
        "Marginal Lift": "The increase in sales attributed to a specific promotion",
        "RMSPE": "Root Mean Square Percentage Error (Official Rossmann evaluation metric)",
        # "Term": "Definition"
    },
    "cost_benefit": "The cost of model development is student time and the benefits are optimized inventory and reduced waste"
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Data Science Student"
#     ],
#     "data_sources": [
#       "Rossmann Store Sales Dataset [Kaggle]"
#     ],
#     "computing": "Local Machine/VS Code environment",
#     "software": [
#       "Python 3.10",
#       "Pandas",
#       "Scikit-learn",
#       "Jupyter"
#     ]
#   },
#   "requirements": [
#     "Project must follow CRISP-DM framework",
#     "Final report due 14th April 2026",
#     "Code must be modular and PEP8 compliant"
#   ],
#   "assumptions": [
#     "Historical sales patterns from 2015 are applicable for predictive modeling",
#     "External holiday data can be successfully merged with store dataInventory must be optimized and not just raw prediction accuracy"
#   ],
#   "constraints": [
#     "Individual project which means no collaboration allowed",
#     "Computing power limited to local hardware"
#   ],
#   "risks_and_contingencies": [
#     {
#       "risk": "Data quality issues (missing values in store.csv)",
#       "probability": "High",
#       "mitigation": "Perform rigorous data auditing and imputation in Phase 2/3"
#     },
#     {
#       "risk": "Scraping failure due to website layout changes",
#       "probability": "Medium",
#       "mitigation": "Use robust selectors and have a static backup CSV of external data if live scraping fails."
#     },
#     {
#       "risk": "Data leakage (using future information to predict the past)",
#       "probability": "Medium",
#       "mitigation": "Maintain a strict temporal split between training and test sets during Phase 4."
#     }
#   ],
#   "terminology": {
#     "MAPE": "Mean Absolute Percentage Error",
#     "Marginal Lift": "The increase in sales attributed to a specific promotion",
#     "RMSPE": "Root Mean Square Percentage Error (Official Rossmann evaluation metric)"
#   },
#   "cost_benefit": "The cost of model development is student time and the benefits are optimized inventory and reduced waste"
# }

# %%
# Optional: Add any further notes or elaboration on the situation assessment
"This assessment simply highlights that while technical accuracy is the primary goal, the project's success is actually dependent on also maintaining professional documentation and a clean version control history to meet the specific marking criteria."
# Out:
# "This assessment simply highlights that while technical accuracy is the primary goal, the project's success is actually dependent on also maintaining professional documentation and a clean version control history to meet the specific marking criteria."

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# TODO: Define data mining goals here.

data_mining_goals = {
    "problem_type": "Regression",  # e.g., "Binary Classification", "Regression", "Clustering"
    "target_variable": "sales",  # e.g., "customer_churn", "house_price"
    "technical_goals": [
        "Goal 1: Build a supervised learning model to predict daily store sales for 1,115 stores.",
        "Goal 2: Quantify the feature importance of 'Promo' and 'Promo2' to evaluate marginal lift (Q2).",
        "Goal 3: Perform time-series feature engineering to capture holiday and seasonality effects.",
        "Goal 4: Construct a time-series feature engineering pipeline to transform 'Date' into cyclical features (DayOfWeek, Month, Seasonality)."
    ],
    "success_metrics": [
        "Metric 1: Achieve a Root Mean Square Percentage Error (RMSPE) < 0.15 on the test set (industry-standard for Rossmann).",
        "Metric 2: Demonstrate a statistically significant correlation between 'Promo' features and 'Sales' lift for the profitability audit.",
        "Metric 3: The final model must maintain a processing latency of < 1 second per store to ensure scalability for 3,000+ locations.",
        "Metric 4: Successful 'Feature Importance' ranking that logically aligns with known retail patterns (Weekends/Promos being top drivers)."

    ]
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ============================================================
# BUSINESS TO DATA MINING GOAL MAPPING
# ============================================================
#
# Business Objective : To accurately forecast daily sales revenue 6 weeks in advance to ensure inventory levels are sufficient for the 'Holiday Season' without overstocking. To determine the marginal lift in sales caused by 'Promo' events and evaluate if this lift justifies the cost of the discount.
# Problem Type       : Regression
# Target Variable    : sales
#
# Technical Goals:
#   - Goal 1: Build a supervised learning model to predict daily store sales for 1,115 stores.
#   - Goal 2: Quantify the feature importance of 'Promo' and 'Promo2' to evaluate marginal lift (Q2).
#   - Goal 3: Perform time-series feature engineering to capture holiday and seasonality effects.
#   - Goal 4: Construct a time-series feature engineering pipeline to transform 'Date' into cyclical features (DayOfWeek, Month, Seasonality).
#
# Success Metrics:
#   - Metric 1: Achieve a Root Mean Square Percentage Error (RMSPE) < 0.15 on the test set (industry-standard for Rossmann).
#   - Metric 2: Demonstrate a statistically significant correlation between 'Promo' features and 'Sales' lift for the profitability audit.
#   - Metric 3: The final model must maintain a processing latency of < 1 second per store to ensure scalability for 3,000+ locations.
#   - Metric 4: Successful 'Feature Importance' ranking that logically aligns with known retail patterns (Weekends/Promos being top drivers).

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
# TODO: Produce your project plan here.

project_plan = {
    "tools": [
        "Python 3.10", "Pandas", "Scikit-Learn", "XGBoost", 
        "Matplotlib/Seaborn", "Git/GitHub", "BeautifulSoup/Requests (Web Scraping)"
    ],
    "techniques": [
        "Web Scraping & Data Augmentation (State/School Holidays)",
        "Time-Series Feature Engineering (Cyclical encoding of dates)",
        "Tree-based Regression (Random Forest, XGBoost)",
        "Feature Importance / SHAP Analysis (for Q2 Marginal Lift)"
    ],
    "timeline": [
       {"phase": "1. Business Understanding", "duration": "Completed", "status": "Done"},
        {"phase": "2. Data Understanding", "duration": "Late March", "status": "Next"},
        {"phase": "3. Data Preparation", "duration": "Late March", "status": "Planned"},
        {"phase": "4. Modeling", "duration": "Early April", "status": "Planned"},
        {"phase": "5. Evaluation", "duration": "Early April", "status": "Planned"},
        {"phase": "6. Deployment", "duration": "Early April", "status": "Planned"}
    ],
    "dependencies": [
        "The external weather and holiday data must be successfully scraped before Data Preparation (Phase 3) can be finalized.",
        "The local machine must be able to handle the 1M+ row dataset in RAM, otherwise a random sample must be used for initial pipeline testing.",
        "GitHub repository must be updated incrementally throughout the timeline to avoid 'Big Bang' upload."
    ],
    "tool_justification": "Pandas is basically selected for memory-efficient manipulation of the 1M+ row training set, though PySpark and it would be recommended if scaling to a 10TB+ Big Data environment. XGBoost is chosen over simple linear models for its superior handling of non-linear retail seasonality and ease of extracting feature importance for the Q2 analysis and also BeautifulSoup is required to fulfill the external data augmentation criteria."
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ============================================================
# PROJECT PLAN
# ============================================================
#
# Tools: Python 3.10, Pandas, Scikit-Learn, XGBoost, Matplotlib/Seaborn, Git/GitHub, BeautifulSoup/Requests (Web Scraping)
# Techniques: Web Scraping & Data Augmentation (State/School Holidays), Time-Series Feature Engineering (Cyclical encoding of dates), Tree-based Regression (Random Forest, XGBoost), Feature Importance / SHAP Analysis (for Q2 Marginal Lift)
#
# Timeline:
#   [    Done    ] 1. Business Understanding | Completed
#   [    Next    ] 2. Data Understanding     | Late March
#   [  Planned   ] 3. Data Preparation       | Late March
#   [  Planned   ] 4. Modeling               | Early April
#   [  Planned   ] 5. Evaluation             | Early April
#   [  Planned   ] 6. Deployment             | Early April
#
# Dependencies:
#   - The external weather and holiday data must be successfully scraped before Data Preparation (Phase 3) can be finalized.
#   - The local machine must be able to handle the 1M+ row dataset in RAM, otherwise a random sample must be used for initial pipeline testing.
#   - GitHub repository must be updated incrementally throughout the timeline to avoid 'Big Bang' upload.
#
# Tool Justification: Pandas is basically selected for memory-efficient manipulation of the 1M+ row training set, though PySpark and it would be recommended if scaling to a 10TB+ Big Data environment. XGBoost is chosen over simple linear models for its superior handling of non-linear retail seasonality and ease of extracting feature importance for the Q2 analysis and also BeautifulSoup is required to fulfill the external data augmentation criteria.

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ============================================================
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ============================================================
#
# Primary Objective  : To accurately forecast daily sales revenue 6 weeks in advance to ensure inventory levels are sufficient for the 'Holiday Season' without overstocking. To determine the marginal lift in sales caused by 'Promo' events and evaluate if this lift justifies the cost of the discount.
# Problem Type       : Regression
# Target Variable    : sales
# Tools Planned      : Python 3.10, Pandas, Scikit-Learn, XGBoost, Matplotlib/Seaborn, Git/GitHub, BeautifulSoup/Requests (Web Scraping)
# Techniques Planned : Web Scraping & Data Augmentation (State/School Holidays), Time-Series Feature Engineering (Cyclical encoding of dates), Tree-based Regression (Random Forest, XGBoost), Feature Importance / SHAP Analysis (for Q2 Marginal Lift)
